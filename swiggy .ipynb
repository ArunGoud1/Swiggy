# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt              # import all required packages
import seaborn as sns

# %%
Arun = pd.read_csv('swiggy.csv')      # load the dataset

# %%
Arun.head()      # head is used for first 5 rows
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
Arun.tail()            # tail is used for last 5 rows
# Out:
#           ID                    Area       City                Restaurant  \
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings                   Food type  \
# 8675  500.0          2.9             80                      Pizzas
# 8676  200.0          2.9             80                South Indian
# 8677  150.0          2.9             80      Chinese,Snacks,Tandoor
# 8678  150.0          2.9             80  North Indian,Indian,Snacks
# 8679  250.0          2.9             80        Chaat,Snacks,Chinese
#
#           Address  Delivery time
# 8675  Navrangpura             40
# 8676       Rohini             28
# ...

# %%
Arun.shape
# Out:
# (8680, 10)

# %%
Arun.size
# Out:
# 86800

# %%
Arun.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %%
Arun.isnull()           # it shows whole dataset
# Out:
#          ID   Area   City  Restaurant  Price  Avg ratings  Total ratings  \
# 0     False  False  False       False  False        False          False
# 1     False  False  False       False  False        False          False
# 2     False  False  False       False  False        False          False
# 3     False  False  False       False  False        False          False
# 4     False  False  False       False  False        False          False
# ...     ...    ...    ...         ...    ...          ...            ...
# 8675  False  False  False       False  False        False          False
# 8676  False  False  False       False  False        False          False
# 8677  False  False  False       False  False        False          False
# 8678  False  False  False       False  False        False          False
# 8679  False  False  False       False  False        False          False
#
#       Food type  Address  Delivery time
# 0         False    False          False
# ...

# %%
Arun.isna().any()
# Out:
# ID               False
# Area             False
# City             False
# Restaurant       False
# Price            False
# Avg ratings      False
# Total ratings    False
# Food type        False
# Address          False
# Delivery time    False
# dtype: bool

# %%
Arun.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
Arun.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
Arun['City'].value_counts()
# Out:
# City
# Kolkata      1346
# Mumbai       1277
# Chennai      1106
# Pune         1090
# Hyderabad    1075
# Bangalore     946
# Ahmedabad     717
# Delhi         611
# Surat         512
# Name: count, dtype: int64

# %%
len(A)
# Out:
# 9

# %%
Arun['Area'].value_counts()
# Out:
# Area
# Rohini                    257
# Chembur                   208
# Kothrud                   149
# Andheri East              135
# Navrangpura               132
#                          ...
# Shakurpur                   1
# Magob                       1
# Bosepukur                   1
# Ambegaon                    1
# Panjarapole Cross Road      1
# Name: count, Length: 833, dtype: int64

# %%
a = Arun[Arun['City'] == 'Bangalore']

# %%
a
# Out:
#           ID                       Area       City         Restaurant  Price  \
# 0        211                Koramangala  Bangalore        Tandoor Hut  300.0
# 1        221                Koramangala  Bangalore      Tunday Kababi  300.0
# 2        246                  Jogupalya  Bangalore            Kim Lee  650.0
# 3        248                Indiranagar  Bangalore  New Punjabi Hotel  250.0
# 4        249                Indiranagar  Bangalore                Nh8  350.0
# ...      ...                        ...        ...                ...    ...
# 8626  455120                   Majestic  Bangalore      Mejestic Cafe  250.0
# 8647  457452  Sanjay Nagar New Bel Road  Bangalore   Sri Ramji Sweets   75.0
# 8648  457630                  Jayanagar  Bangalore      Sri Sai Foods  149.0
# 8664  461164                   Majestic  Bangalore  Himadri Ice Cream  250.0
# 8669  462943          Central Bangalore  Bangalore    Bangarpet Chats  110.0
#
#       Avg ratings  Total ratings  \
# ...

# %%
a = Arun[(Arun['City'] == 'Bangalore') & (Arun['Area'] == 'Koramangala')]

# %%
a
# Out:
#           ID         Area       City  \
# 0        211  Koramangala  Bangalore
# 1        221  Koramangala  Bangalore
# 7        263  Koramangala  Bangalore
# 9        308  Koramangala  Bangalore
# 10       435  Koramangala  Bangalore
# ...      ...          ...        ...
# 8137  366890  Koramangala  Bangalore
# 8294  403775  Koramangala  Bangalore
# 8301  405127  Koramangala  Bangalore
# 8506  442032  Koramangala  Bangalore
# 8600  452240  Koramangala  Bangalore
#
#                                         Restaurant  Price  Avg ratings  \
# 0                                      Tandoor Hut  300.0          4.4
# 1                                    Tunday Kababi  300.0          4.1
# 7     Cupcake Noggins - Cakespastries And Desserts  150.0          4.3
# 9                                       Bangaliana  300.0          4.0
# 10                             Bamey'S Restro Cafe  400.0          4.4
# ...                                            ...    ...          ...
# ...

# %%
Arun['Delivery time'].max()
# Out:
# 109

# %%
Arun['Delivery time']>=109
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8675    False
# 8676    False
# 8677    False
# 8678    False
# 8679    False
# Name: Delivery time, Length: 8680, dtype: bool

# %%
s = Arun[Arun['Delivery time']>=109]

# %%
s.head()
# Out:
#           ID      Area     City       Restaurant  Price  Avg ratings  \
# 5327  422757  Kestopur  Kolkata  Heavens Kitchen  300.0          2.9
#
#       Total ratings Food type    Address  Delivery time
# 5327             80    Indian  Salt Lake            109

# %%
s = Arun.nlargest(5,'Delivery time')

# %%
s
# Out:
#           ID        Area     City                      Restaurant  Price  \
# 5327  422757    Kestopur  Kolkata                 Heavens Kitchen  300.0
# 5707  438993  Santoshpur  Kolkata   Yin Yang - Pan Asian Delicacy  500.0
# 3134  310906  Tollygunge  Kolkata  Fatty Mamma Chinese Restaurant  800.0
# 4834  400849   Lake Town  Kolkata                        Sandwizz  199.0
# 5696  438514      Dumdum  Kolkata            Tamang'S Frozen Momo  200.0
#
#       Avg ratings  Total ratings         Food type     Address  Delivery time
# 5327          2.9             80            Indian   Salt Lake            109
# 5707          2.9             80  Chinese,Desserts  Santoshpur            100
# 3134          2.9             80           Chinese  Russa Road             98
# 4834          2.9             80         Fast Food   Lake Town             98
# 5696          2.9             80    Chinese,Pastas      Dumdum             98

# %%
A = Arun.drop('City',axis = 1)      # is used to delete the coloumn

# %%
A
# Out:
#           ID                    Area                Restaurant  Price  \
# 0        211             Koramangala               Tandoor Hut  300.0
# 1        221             Koramangala             Tunday Kababi  300.0
# 2        246               Jogupalya                   Kim Lee  650.0
# 3        248             Indiranagar         New Punjabi Hotel  250.0
# 4        249             Indiranagar                       Nh8  350.0
# ...      ...                     ...                       ...    ...
# 8675  464626  Panjarapole Cross Road                Malt Pizza  500.0
# 8676  465835                  Rohini  Jay Mata Ji Home Kitchen  200.0
# 8677  465872                  Rohini      Chinese Kitchen King  150.0
# 8678  465990                  Rohini    Shree Ram Paratha Wala  150.0
# 8679  466488             Navrangpura              Sassy Street  250.0
#
#       Avg ratings  Total ratings  \
# 0             4.4            100
# 1             4.1            100
# ...

# %% [markdown]
# ## Data Visuvalization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt              # import all required packages
import seaborn as sns

# %%
data = pd.read_csv('swiggy.csv')

# %%
sns.countplot(data = data,x="City")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.barplot(data = data ,x = "City",y = "Price")
# Out:
# <Axes: xlabel='City', ylabel='Price'>

# %%
sns.lineplot(data = data, x="Food type",y="Price")
# Out:
# <Axes: xlabel='Food type', ylabel='Price'>

# %%
import seaborn as sns

# %%
sns.scatterplot(data = data, x="Food type",y="Price")
# Out:
# <Axes: xlabel='Food type', ylabel='Price'>

# %%
import seaborn as sns

# %%
sns.swarmplot(data = data ,x="Food type",y="Price")
# Out:
# C:\Users\arung\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\arung\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\arung\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\arung\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 76.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.boxplot(data = data,x="Price",y="City")
# Out:
# <Axes: xlabel='Price', ylabel='City'>
